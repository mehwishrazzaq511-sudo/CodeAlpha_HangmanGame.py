# %%
import random

print("=" * 40)
print("      🎮 HANGMAN GAME 🎮")
print("=" * 40)

# List of words
words = ["python", "computer", "internship", "coding", "developer"]

# Select random word
word = random.choice(words)

guessed_letters = []
wrong_guesses = 0
max_wrong = 6

while wrong_guesses < max_wrong:

    display_word = ""

    for letter in word:
        if letter in guessed_letters:
            display_word += letter + " "
        else:
            display_word += "_ "

    print("\nWord:", display_word)

    # Check Win
    if "_" not in display_word:
        print("\n🎉 Congratulations! You guessed the word correctly.")
        break

    guess = input("Guess a letter: ").lower()

    # Validate Input
    if len(guess) != 1 or not guess.isalpha():
        print("❌ Please enter only one alphabet.")
        continue

    if guess in guessed_letters:
        print("⚠️ You already guessed this letter.")
        continue

    guessed_letters.append(guess)

    if guess in word:
        print("✅ Correct Guess!")
    else:
        wrong_guesses += 1
        print("❌ Wrong Guess!")
        print("Remaining Chances:", max_wrong - wrong_guesses)

else:
    print("\n💀 Game Over!")
    print("The correct word was:", word)

print("\nThank you for playing Hangman!")
# Out:
# ========================================
#       🎮 HANGMAN GAME 🎮
# ========================================
#
# Word: _ _ _ _ _ _ _ _ _
# Guess a letter:  1
# ❌ Please enter only one alphabet.
#
# Word: _ _ _ _ _ _ _ _ _
# Guess a letter:  S
# ❌ Wrong Guess!
# Remaining Chances: 5
#
# Word: _ _ _ _ _ _ _ _ _
# Guess a letter:  M
# ❌ Wrong Guess!
# Remaining Chances: 4
#
# Word: _ _ _ _ _ _ _ _ _
# Guess a letter:  i
# ❌ Wrong Guess!
# Remaining Chances: 3
#
# Word: _ _ _ _ _ _ _ _ _
# Guess a letter:  p
# ✅ Correct Guess!
#
# Word: _ _ _ _ _ _ p _ _
# Guess a letter:  d
# ✅ Correct Guess!
#
# Word: d _ _ _ _ _ p _ _
# Guess a letter:  e
# ✅ Correct Guess!
#
# Word: d e _ e _ _ p e _
# Guess a letter:  v
# ✅ Correct Guess!
#
# Word: d e v e _ _ p e _
# Guess a letter:  l
# ✅ Correct Guess!
#
# Word: d e v e l _ p e _
# Guess a letter:  e
# ⚠️ You already guessed this letter.
#
# Word: d e v e l _ p e _
# Guess a letter:  r
# ✅ Correct Guess!
#
# Word: d e v e l _ p e r
# Guess a letter:  o
# ✅ Correct Guess!
#
# Word: d e v e l o p e r
#
# 🎉 Congratulations! You guessed the word correctly.
#
# Thank you for playing Hangman!
